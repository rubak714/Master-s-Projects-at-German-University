# %% [markdown]
# # DSP Lab 2: Stochastic Processes, matriculation number: 11146364
# Generated on: 09.01.2022 at: 19:23:22 h.
# ### Please execute the next code cells to start your lab/homework!

# %%
# iPython magic command to load the matplotlib library and
# select the notebook graphics frontend
# %matplotlib inline
# import necessary functions from the thkdss library
from thkdsp import *
from dsplab import *
# import audio related functions from the audio submodule
#from thkdsp.audio import play_signal, wav2dtsignal
# import some definitions and functions from numpy, the python library for Matlab-like array processing
from numpy import arange, shape, array, zeros, size, ones, isscalar

# %%
# set font for Matplotlib to 'Times New Roman' if that is available
set_mpl_font()
# set default font size for Matplotlib, change to different value if labels are too large or too small
set_mpl_fontsize(16)

# %%
# start homework
dsp_lab2_start()
# Out:
# TH Köln University of Applied Sciences
# Course:  Digital Signal Processing
# Lab 2: Stochastic Processes
#
# You are about to start Lab 2: Stochastic Processes !
# Please read and follow the instructions exactly as stated!
#
# You will be asked to enter your matriculation number.
# Please make sure that you enter it correctly!
#
# Please enter your 8-digit matriculation number: 11146364
# Your matriculation number is:  11146364
# Is this correct? yes/no: yes
# Starting output to log file for Lab 2: Stochastic Processes for matriculation number: 11146364
# dsp_lab2_11146364.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : dsp_lab2_11146364.log
# Mode           : append
# Output logging : True
# Raw input log  : True
# Timestamping   : True
# State          : active
# Info: 4722224406
# Lab 2: Stochastic Processes for matriculation number 11146364 started at: 2022-01-09 19:28:07.188972

# %% [markdown]
# ### Enter as many code cells as you need below!
# ### Note: Your notebook needs to be modular enough, i.e. it has to consist of enough code cells!
# ### Otherwise, your submission will be considered as not sufficient!

# %%
#Importing the functions used in this lab
from dsplab.lab2 import *

# %% [markdown]
#  Lab 1: Sample functions of different stochastic processes

# %%
#Generate a segment of duration T = 2s for each sample function and M = 10000 sample functions for each process

# %%
T = 2

# %%
M = 10000

# %%
#N=1,2,3,4,5
#The function urp can be used to generate sample functions of five unknown random processes

# %%
t1, s1 = urp(M, T, 1)

# %%
t2, s2 = urp(M, T, 2)

# %%
t3, s3 = urp(M, T, 3)

# %%
t4, s4 = urp(M, T, 4)

# %%
t5, s5 = urp(M, T, 5)

# %%
plot_ensemble?

# %%
plot_ensemble(t1, s1)

# %%
plot_ensemble(t2, s2)

# %%
plot_ensemble(t3, s3)

# %%
plot_ensemble(t4, s4)

# %%
plot_ensemble(t5, s5)

# %% [markdown]
# Lab 2: Testing for stationarity

# %%
from numpy import mean

# %%
fig, ax = plot_signal(t1, mean(s1, 0), plotaxes = False, label = "1")

# %%
fig, ax = plot_signal(t2, mean(s2, 0), plotaxes = False, figure = fig, axes = ax, label = "2")

# %%
fig, ax = plot_signal(t3, mean(s3, 0), plotaxes = False, figure = fig, axes = ax, label = "3")

# %%
fig, ax = plot_signal(t4, mean(s4, 0), plotaxes = False, figure = fig, axes = ax, label = "4")

# %%
fig, ax = plot_signal(t5, mean(s5, 0), figure = fig, axes = ax, label = "5")

# %%
ax.axis("auto")
# Out:
# (-0.09950000000000006, 2.0895, -4.4822003051943256, 4.461988819575081)

# %%
ax.legend()

# %%
fig

# %% [markdown]
# Comment: The five random processes are of non-stationary random process

# %%
##########################################################################################

# %% [markdown]
# Lab 3: Autocorrelation function of stationary random processes

# %%
tau1, varphi1 = acf_ensemble(t1, s1)

# %%
tau2, varphi2 = acf_ensemble(t2, s2)

# %%
tau3, varphi3 = acf_ensemble(t3, s3)

# %%
tau4, varphi4 = acf_ensemble(t4, s4)

# %%
plot_acf?

# %%
plot_acf(tau1, varphi1)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
plot_acf(tau2, varphi2)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
plot_acf(tau3, varphi3)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
plot_acf(tau4, varphi4)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %% [markdown]
# Comment: URP 1 and 3 are seemed to be harmonic and URP 2 and 4 are stationary

# %% [markdown]
# Lab 4: Estimation of the power density spectrum

# %%
T = 10

# %%
M = 1000

# %%
t1, s1 = urp(M, T, 1)

# %%
t2, s2 = urp(M, T, 2)

# %%
t3, s3 = urp(M, T, 3)

# %%
t4, s4 = urp(M, T, 4)

# %%
plot_ensemble_tf(t1, s1)

# %%
plot_ensemble_tf(t2, s2)

# %%
plot_ensemble_tf(t3, s3)

# %%
plot_ensemble_tf(t4, s4)

# %%
f1, phi1 = pds_ensemble(t1, s1)

# %%
f2, phi2 = pds_ensemble(t2, s2)

# %%
f3, phi3 = pds_ensemble(t3, s3)

# %%
f4, phi4 = pds_ensemble(t4, s4)

# %%
plot_pds(f1, phi1)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
plot_pds(f2, phi2)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
plot_pds(f3, phi3)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
plot_pds(f4, phi4)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %% [markdown]
# Comment: URP 1 and 4 are called as HPN and URP 2 and 3 are known as LPN

# %% [markdown]
# Lab 5: Discrete-time white noise

# %%
T = 10

# %%
r = 48000

# %%
t_s, s = wgn(1/r, T, 1, r)

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin = 0, xmax = 0.05)

# %%
tau_s, varphi_ss = acf_time(t_s, s, 0.05)

# %%
acf_fig, acf_ax = plot_acf(tau_s, varphi_ss)

# %%
f_s, PHI_ss = pds_time(t_s, s)

# %%
pds_fig, pds_ax = plot_pds(f_s, PHI_ss)

# %%
from thkdsp.audio import play_signal, wav2dtsignal
#HTTP error
#import unsuccessful
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5800/22408545.py in <module>
# ----> 1 from thkdsp.audio import play_signal, wav2dtsignal
#
# ~\final dsp lab1\DSP\thkdsp\audio.py in <module>
#      48                 data = data.encode('ascii ') # data should be bytes
#      49                 req = urllib.request.Request(url, data, method='GET')
# ---> 50                 with urllib.request.urlopen(req) as response:
#      51                     web_page = response.read()
#      52                 # Check if in notebook running on Jupyterhub server
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
#play_signal(t_s, s)

# %% [markdown]
# Lab 6: Moving average of white noise

# %%
T_d = 0.001

# %%
r = 48000

# %%
t_d, d = gen_dirac(T_d, r)

# %%
T = 1/4800

# %%
t_h, h = moving_average(t_d, d, T)

# %%
plot_signal(t_h, h, ylabel = "h")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ h(t) \\rightarrow$'>)

# %%
t_g, g = moving_average(t_s, s, T)

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin = 0, xmax = 0.05, plotaxes = False)

# %%
plot_signal(t_g, g, xmax = 0.05, figure = signal_fig, axes = signal_ax, color = "r")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %%
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %%
signal_fig
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Comment: the s(t) signal is more arbitrary than output g(t) signal

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin = 0.01, xmax = 0.015, plotaxes = False)

# %%
plot_signal(t_g, g, xmin = 0.01, xmax = 0.015, figure = signal_fig, axes = signal_ax, color = "r")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %%
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %%
signal_fig

# %% [markdown]
# Comment: The faster oscillations are removed from output signal that's why it seems to be smoother than input signal

# %%
tau_g, varphi_gg = acf_time(t_g, g, 0.001)

# %%
plot_acf(tau_g, varphi_gg, xmin = -0.001, xmax = 0.001)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
f_g, PHI_gg = pds_time(t_g, g)

# %%
pds_fig, pds_ax = plot_pds(f_s, PHI_ss)

# %%
plot_pds(f_g, PHI_gg, figure = pds_fig, axes = pds_ax, color = "r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
pds_fig

# %%
play_signal(t_g, g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5800/1968516332.py in <module>
# ----> 1 play_signal(t_g, g)
#
# NameError: name 'play_signal' is not defined

# %% [markdown]
# #

# %% [markdown]
# Lab 7: Ideal lowpass with discrete-time white noise input

# %%
t_ma = t_g

# %%
g_ma = g

# %%
T_d = 0.01

# %%
r = 48000

# %%
t_d, d = gen_dirac(T_d, r)

# %%
f_c = 4800

# %%
t_h, h = low_pass(t_d, d, f_c)

# %%
plot_signal(t_h, h)
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %%
t_g, g = low_pass(t_s, s, f_c)

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin = 0, xmax = 0.05, plotaxes = False)

# %%
plot_signal(t_g, g, xmax = 0.05, figure = signal_fig, axes = signal_ax, color = "r")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %%
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %%
signal_fig
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Comment: Noise is filtered notably from output signal in comparison with the input noise signal

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin = 0.01, xmax = 0.015, plotaxes = False)

# %%
plot_signal(t_g, g, xmin = 0.01, xmax = 0.015, figure = signal_fig, axes = signal_ax, color = "r")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %%
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %%
signal_fig

# %% [markdown]
# Comment: The output singal is acknowledged as much even than the input noise signal

# %%
tau_g, varphi_gg = acf_time(t_g, g, 0.001)

# %%
plot_acf(tau_g, varphi_gg, xmin = -0.001, xmax = 0.001)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
f_g, PHI_gg = pds_time(t_g, g)

# %%
pds_fig, pds_ax = plot_pds(f_s, PHI_ss)

# %%
plot_pds(f_g, PHI_gg, figure = pds_fig, axes = pds_ax, color = "r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
pds_fig

# %%
#following lines could not be executed for failure in importing audio file from thkdsp.Therefore, these are kept as comment

# %%
#play_signal(t_g, g)

# %%
#play_signal(t_s, s)

# %%
#play_signal(t_ma, g_ma)

# %%
#play_signal(t_g, g)

# %% [markdown]
# ### When you run the command in the next code cell, the lab/homework will be finished!
# ### Execute the next code cell only if you really want to finish this lab/homework!
# ### This code cell should be your last code cell!

# %%
# finish homework
dsp_lab2_finish()
# Out:
# You are about to finish Lab 2: Stochastic Processes !
# This will finish output to the log file, such that you should not enter any command after finishing!
#
# Thus, proceed only if you are sure that you are really finished!!
# Do you really want to finish? yes/no: 11146364
# Please enter "yes" or "no"!
# Do you really want to finish? yes/no: yes
# Finishing Lab 2: Stochastic Processes for matriculation number 11146364
# Lab 2: Stochastic Processes  finished at: 2022-01-09 23:07:09.974003
# Finished after: 3:39:02.785031
# Info:  4722224406
# Congratulations! You have just finished Lab 2: Stochastic Processes !
#
# In your current working directory you will find the following Log file:
#
# Log file:  dsp_lab2_11146364.log
#
# Please save this iPython notebook one more time!
#
# Please upload both files to the ILIAS server:
# If this is a homework, use the 'Homework' folder of the ILIAS DSP internet pages!
# If this is a lab, use the 'Lab' folder of the ILIAS DSP internet pages!
#
# In either case you will be notified on the status of your submission via email.
#
# So stay tuned!
# Harald Elders-Boll

# %% [markdown]
# ### Please save this notebook one more time!
